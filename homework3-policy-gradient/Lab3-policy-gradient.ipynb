# %%
# Automatically reload changes to external code
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this assignment, you will solve a classic control problem - CartPole using policy gradient methods.
#
# Policy gradient method is a family of RL algorithms that parameterizes the policy directly. The simplest advantage that policy parameterization may have over action-value parameterization is that the policy may be a simpler function to approximate.
#
# First, you will implement the "vanilla" policy gradient method, i.e., a method that repeatedly computes **unbiased** estimates $\hat{g}$ of $\nabla_{\theta} E[\sum_t r_t]$ and takes gradient ascent steps $\theta \rightarrow \theta + \epsilon \hat{g}$ so as to increase the total rewards collected in each episode. To make sure our code can solve multiple MDPs with different policy parameterizations, provided code follows an OOP manner and represents MDP and Policy as classes.
#
# The following code constructs an instance of the MDP using OpenAI gym.

# %%
import gym
import tensorflow as tf
import numpy as np
from policy_gradient import util
from policy_gradient.policy import CategoricalPolicy
from policy_gradient.baselines.linear_feature_baseline import LinearFeatureBaseline

np.random.seed(0)
tf.set_random_seed(0)

# CartPole-v0 is a MDP with finite state and action space. 
# In this environment, A pendulum is attached by an un-actuated joint to a cart, 
# and the goal is to prevent it from falling over. You can apply a force of +1 or -1 to the cart.
# A reward of +1 is provided for every timestep that the pendulum remains upright. 
# To visualize CartPole-v0, please see https://gym.openai.com/envs/CartPole-v0

env = gym.make('CartPole-v0')
# Out:
# [2017-11-08 20:14:52,964] Making new env: CartPole-v0

# %% [markdown]
# ## Problem 1: construct a neural network to represent policy
#
# Make sure you know how to construct neural network using tensorflow.
#
# 1. Open **homework2/policy_gradient/policy.py**.
# 2. Follow the instruction of Problem 1.

# %% [markdown]
# ## Problem 2: compute the surrogate loss
#
# If there are $N$ episodes in an iteration, then for $i$ th episode we define $R_t^i = \sum_{{t^′}=t}^T \gamma^{{t^′}-t}r(s_{t^′}, a_{t^′})$ as the accumulated discounted rewards from timestep $t$ to the end of that episode, where $\gamma$ is the discount rate.
#
# The pseudocode for the REINFORCE algorithm is as below:
#
# 1. Initialize policy $\pi$ with parameter $\theta_1$.
# 2. For iteration $k = 1, 2, ...$:
#     * Sample N episodes $\tau_1, \tau_2, ..., \tau_N$ under the current policy $\theta_k$, where $\tau_i =(s_i^t,a_i^t,R_i^t)_{t=0}^{T−1}$. Note that the last state is dropped since no action is taken after observing the last state.
#     * Compute the empirical policy gradient using formula: $$\hat{g} = E_{\pi_\theta}[\nabla_{\theta} log\pi_\theta(a_t^i | s_t^i) R_t^i]$$
#     * Take a gradient step: $\theta_{k+1} = \theta_k + \epsilon \hat{g}$.
#
#
# Note that we can transform the policy gradient formula as
#
# $$\hat{g} = \nabla_{\theta} \frac{1}{(NT)}(\sum_{i=1}^N \sum_{t=0}^T log\pi_\theta(a_t^i | s_t^i) *R_t^i)$$
#
# and $L(\theta) = \frac{1}{(NT)}(\sum_{i=1}^N \sum_{t=0}^T log\pi_\theta(a_t^i | s_t^i) *R_t^i)$ is called the surrogate loss.
#
# We can first construct the computation graph for $L(\theta)$, and then take its gradient as the empirical policy gradient.
#
#
# 1. Open **homework2/policy_gradient/policy.py**.
# 2. Follow the instruction of Problem 2.

# %%
tf.reset_default_graph()
sess = tf.Session()
# Construct a neural network to represent policy which maps observed state to action. 
in_dim = util.flatten_space(env.observation_space)
out_dim = util.flatten_space(env.action_space)
hidden_dim = 8

# Initialize your policy
with tf.variable_scope("policy"):
    opt_p = tf.train.AdamOptimizer(learning_rate=0.01)
    policy = CategoricalPolicy(in_dim, out_dim, hidden_dim, opt_p, sess)
# Out:
# /home/guy/miniconda2/envs/cedl/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:95: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# # Problem 3
#
# Use baseline to reduce the variance of our gradient estimate.
#
# Change the loss term:
#
# $$L(\theta) = \frac{1}{(NT)}(\sum_{i=1}^N \sum_{t=0}^T log\pi_\theta(a_t^i | s_t^i) *R_t^i)$$
#
# into this one
#
# $$L(\theta) = \frac{1}{(NT)}(\sum_{i=1}^N \sum_{t=0}^T log\pi_\theta(a_t^i | s_t^i) *(R_t^i-V_t^i))$$
#
# where $V_t^i$ is the baseline prediction for at the $t$ timestep $i^{th}$ trajectory. In this part, we use a simple linear function to parameterize value function. (You're encouraged to see the details in ```policy_gradient/baselines/linear_feature_baseline.py```)
#
# 1. Fill in the function `process_paths` of class `PolicyOptimizer` below.

# %%
class PolicyOptimizer(object):
    def __init__(self, env, policy, baseline, n_iter, n_episode, path_length,
        discount_rate=.99):

        self.policy = policy
        self.baseline = baseline
        self.env = env
        self.n_iter = n_iter
        self.n_episode = n_episode
        self.path_length = path_length
        self.discount_rate = discount_rate

    def sample_path(self):
        obs = []
        actions = []
        rewards = []
        ob = self.env.reset()

        # sample a batch of trajectory
        for _ in range(self.path_length):
            a = self.policy.act(ob.reshape(1, -1))
            next_ob, r, done, _ = self.env.step(a)
            obs.append(ob)
            actions.append(a)
            rewards.append(r)
            ob = next_ob
            if done:
                break

        return dict(
            observations=np.array(obs),
            actions=np.array(actions),
            rewards=np.array(rewards),
        )

    def process_paths(self, paths):
        for p in paths:
            if self.baseline != None:
                b = self.baseline.predict(p)
                b[-1] = 0 # terminal state
            else:
                b = 0
            
            # `p["rewards"]` is a matrix contains the rewards of each timestep in a sample path
            r = util.discount_cumsum(p["rewards"], self.discount_rate)
            
            """
            Problem 3:

            1. Variable `b` is the values predicted by our baseline
            2. Use it to reduce variance and then assign the result to the 
                    variable `a` (baseline reduction)

            Sample solution should be only 1 line.
            """
            # YOUR CODE HERE >>>>>>
            
            a = r-b
            # <<<<<<<<

            p["returns"] = r
            p["baselines"] = b
            p["advantages"] = (a - a.mean()) / (a.std() + 1e-8) # normalize

        obs = np.concatenate([ p["observations"] for p in paths ])
        actions = np.concatenate([ p["actions"] for p in paths ])
        rewards = np.concatenate([ p["rewards"] for p in paths ])
        advantages = np.concatenate([ p["advantages"] for p in paths ])

        return dict(
            observations=obs,
            actions=actions,
            rewards=rewards,
            advantages=advantages,
        )

    
    def train(self):
        loss_list = []
        avg_return_list = []
        for i in range(1, self.n_iter + 1):
            paths = []
            for _ in range(self.n_episode):
                paths.append(self.sample_path())
            data = self.process_paths(paths)
            loss = self.policy.train(data["observations"], data["actions"], data["advantages"])
            avg_return = np.mean([sum(p["rewards"]) for p in paths])
            print("Iteration {}: Average Return = {}".format(i, avg_return))
            loss_list.append(loss)
            avg_return_list.append(avg_return)
            # CartPole-v0 defines "solving" as getting average reward of 195.0 over 100 consecutive trials.
            if avg_return >= 195:
                print("Solve at {} iterations, which equals {} episodes.".format(i, i*100))
                break

            if self.baseline != None:
                self.baseline.fit(paths)
        return loss_list, avg_return_list

# %%
sess.run(tf.global_variables_initializer())

n_iter = 200
n_episode = 100
path_length = 200
discount_rate = 0.99
baseline = LinearFeatureBaseline(env.spec)


po = PolicyOptimizer(env, policy, baseline, n_iter, n_episode, path_length,
                     discount_rate)

# Train the policy optimizer
loss_list, avg_return_list = po.train()
# Out:
# Iteration 1: Average Return = 24.24
# Iteration 2: Average Return = 30.28
# Iteration 3: Average Return = 29.48
# Iteration 4: Average Return = 33.16
# Iteration 5: Average Return = 33.79
# Iteration 6: Average Return = 36.0
# Iteration 7: Average Return = 39.07
# Iteration 8: Average Return = 38.81
# Iteration 9: Average Return = 48.85
# Iteration 10: Average Return = 43.62
# Iteration 11: Average Return = 46.89
# Iteration 12: Average Return = 46.39
# Iteration 13: Average Return = 48.46
# Iteration 14: Average Return = 52.76
# Iteration 15: Average Return = 56.57
# Iteration 16: Average Return = 53.68
# Iteration 17: Average Return = 55.89
# Iteration 18: Average Return = 58.38
# Iteration 19: Average Return = 62.03
# Iteration 20: Average Return = 59.86
# Iteration 21: Average Return = 64.34
# Iteration 22: Average Return = 65.16
# Iteration 23: Average Return = 65.53
# Iteration 24: Average Return = 71.15
# Iteration 25: Average Return = 67.16
# Iteration 26: Average Return = 70.22
# Iteration 27: Average Return = 76.64
# Iteration 28: Average Return = 77.6
# Iteration 29: Average Return = 71.9
# Iteration 30: Average Return = 83.67
# Iteration 31: Average Return = 83.88
# Iteration 32: Average Return = 91.99
# Iteration 33: Average Return = 91.52
# Iteration 34: Average Return = 98.41
# Iteration 35: Average Return = 103.21
# Iteration 36: Average Return = 109.6
# Iteration 37: Average Return = 112.41
# Iteration 38: Average Return = 123.25
# Iteration 39: Average Return = 130.5
# Iteration 40: Average Return = 136.17
# Iteration 41: Average Return = 138.23
# Iteration 42: Average Return = 138.9
# Iteration 43: Average Return = 145.03
# Iteration 44: Average Return = 140.25
# Iteration 45: Average Return = 151.0
# Iteration 46: Average Return = 137.39
# Iteration 47: Average Return = 141.76
# Iteration 48: Average Return = 154.55
# Iteration 49: Average Return = 152.54
# Iteration 50: Average Return = 143.11
# Iteration 51: Average Return = 156.59
# Iteration 52: Average Return = 155.84
# Iteration 53: Average Return = 149.48
# Iteration 54: Average Return = 164.08
# Iteration 55: Average Return = 165.2
# Iteration 56: Average Return = 171.24
# Iteration 57: Average Return = 177.26
# Iteration 58: Average Return = 173.1
# Iteration 59: Average Return = 178.15
# Iteration 60: Average Return = 177.59
# Iteration 61: Average Return = 189.23
# Iteration 62: Average Return = 187.44
# Iteration 63: Average Return = 190.77
# Iteration 64: Average Return = 195.01
# Solve at 64 iterations, which equals 6400 episodes.

# %%
util.plot_curve(loss_list, "loss")
util.plot_curve(avg_return_list, "average return")

# %% [markdown]
# # Verify your solutions
#
# if you solve the problems 1~3 correctly, your will solve CartPole with roughly ~ 80 iterations.

# %% [markdown]
# # Problem 4
#
# Replacing line
#
# `baseline = LinearFeatureBaseline(env.spec)`
#
# with
#
# `baseline = None`
#
# can remove the baseline.
#
# Modify the code to compare the variance and performance before and after adding baseline. And explain wht the baseline won't introduce bias. Then, write a report about your findings and explainations.

# %%
sess.run(tf.global_variables_initializer())

n_iter = 200
n_episode = 100
path_length = 200
discount_rate = 0.99

baseline = None 

po = PolicyOptimizer(env, policy, baseline, n_iter, n_episode, path_length,
                     discount_rate)

# Train the policy optimizer
loss_list, avg_return_list = po.train()
# Out:
# Iteration 1: Average Return = 25.02
# Iteration 2: Average Return = 26.35
# Iteration 3: Average Return = 27.92
# Iteration 4: Average Return = 32.63
# Iteration 5: Average Return = 34.93
# Iteration 6: Average Return = 37.05
# Iteration 7: Average Return = 37.19
# Iteration 8: Average Return = 39.59
# Iteration 9: Average Return = 37.16
# Iteration 10: Average Return = 38.59
# Iteration 11: Average Return = 39.64
# Iteration 12: Average Return = 44.21
# Iteration 13: Average Return = 44.73
# Iteration 14: Average Return = 49.04
# Iteration 15: Average Return = 43.74
# Iteration 16: Average Return = 48.4
# Iteration 17: Average Return = 55.38
# Iteration 18: Average Return = 53.56
# Iteration 19: Average Return = 56.71
# Iteration 20: Average Return = 58.39
# Iteration 21: Average Return = 56.28
# Iteration 22: Average Return = 55.78
# Iteration 23: Average Return = 64.59
# Iteration 24: Average Return = 72.58
# Iteration 25: Average Return = 69.63
# Iteration 26: Average Return = 73.15
# Iteration 27: Average Return = 81.03
# Iteration 28: Average Return = 82.81
# Iteration 29: Average Return = 87.7
# Iteration 30: Average Return = 84.17
# Iteration 31: Average Return = 93.96
# Iteration 32: Average Return = 93.64
# Iteration 33: Average Return = 101.03
# Iteration 34: Average Return = 99.21
# Iteration 35: Average Return = 106.13
# Iteration 36: Average Return = 115.66
# Iteration 37: Average Return = 105.28
# Iteration 38: Average Return = 114.37
# Iteration 39: Average Return = 118.81
# Iteration 40: Average Return = 118.22
# Iteration 41: Average Return = 122.21
# Iteration 42: Average Return = 128.92
# Iteration 43: Average Return = 118.79
# Iteration 44: Average Return = 142.55
# Iteration 45: Average Return = 140.44
# Iteration 46: Average Return = 149.32
# Iteration 47: Average Return = 140.99
# Iteration 48: Average Return = 157.24
# Iteration 49: Average Return = 146.12
# Iteration 50: Average Return = 155.64
# Iteration 51: Average Return = 162.85
# Iteration 52: Average Return = 169.13
# Iteration 53: Average Return = 167.21
# Iteration 54: Average Return = 164.51
# Iteration 55: Average Return = 176.55
# Iteration 56: Average Return = 174.93
# Iteration 57: Average Return = 178.13
# Iteration 58: Average Return = 179.76
# Iteration 59: Average Return = 174.11
# Iteration 60: Average Return = 176.87
# Iteration 61: Average Return = 179.31
# Iteration 62: Average Return = 177.66
# Iteration 63: Average Return = 185.7
# Iteration 64: Average Return = 183.11
# Iteration 65: Average Return = 184.07
# Iteration 66: Average Return = 183.73
# Iteration 67: Average Return = 180.99
# Iteration 68: Average Return = 188.11
# Iteration 69: Average Return = 182.5
# Iteration 70: Average Return = 186.97
# Iteration 71: Average Return = 190.61
# Iteration 72: Average Return = 190.29
# Iteration 73: Average Return = 191.02
# Iteration 74: Average Return = 192.02
# Iteration 75: Average Return = 190.83
# Iteration 76: Average Return = 189.71
# Iteration 77: Average Return = 192.3
# Iteration 78: Average Return = 189.71
# Iteration 79: Average Return = 190.97
# Iteration 80: Average Return = 187.12
# Iteration 81: Average Return = 191.28
# Iteration 82: Average Return = 191.79
# Iteration 83: Average Return = 192.59
# Iteration 84: Average Return = 192.63
# Iteration 85: Average Return = 193.92
# Iteration 86: Average Return = 191.8
# Iteration 87: Average Return = 193.98
# Iteration 88: Average Return = 193.07
# Iteration 89: Average Return = 195.03
# Solve at 89 iterations, which equals 8900 episodes.

# %%
util.plot_curve(loss_list, "loss")
util.plot_curve(avg_return_list, "average return")

# %% [markdown]
# # Problem 5: Actor-Critic algorithm (with bootstrapping)
#
# The baseline reduction lowers the variance without the cost of introducing bias. Are there any others that can reduce the variance of the policy?
#
# In this part, you will implement a simple actor-critic algorithm. Try to overwrite the `process_paths` in `PolicyOptimizer_actor_critic`. Note that the `PolicyOptimizer_actor_critic` inherit the class `PolicyOptimizer`

# %% [markdown]
# We use the one-step bootstrap for the advantage function, which change the $A_t^i=(R_t^i-V_t^i)$ in problem 3 into:
#
# $$A_t^i = r_t^i + \gamma*V_{t+1}^i - V_t^i$$
#
# Open **policy_gradient/util.py ** to implement the function `discount_bootstrap`
#
# If you answer is right, your will solve CartPole with roughly ~ 80 iterations.

# %%
 def process_paths(self, paths):
        for p in paths:
            if self.baseline != None:
                b = self.baseline.predict(p)
                b[-1] = 0 # terminal state
            else:
                b = 0
            
            # `p["rewards"]` is a matrix contains the rewards of each timestep in a sample path
            r = util.discount_bootstrap(p["rewards"], self.discount_rate, b)  
            a = r-b
            

            p["returns"] = r
            p["baselines"] = b
            p["advantages"] = (a - a.mean()) / (a.std() + 1e-8) # normalize

        obs = np.concatenate([ p["observations"] for p in paths ])
        actions = np.concatenate([ p["actions"] for p in paths ])
        rewards = np.concatenate([ p["rewards"] for p in paths ])
        advantages = np.concatenate([ p["advantages"] for p in paths ])

        return dict(
            observations=obs,
            actions=actions,
            rewards=rewards,
            advantages=advantages,
        )

# %%
sess.run(tf.global_variables_initializer())

n_iter = 200
n_episode = 100
path_length = 200
discount_rate = 0.99

baseline = LinearFeatureBaseline(env.spec)

po = PolicyOptimizer(env, policy, baseline, n_iter, n_episode, path_length,
                     discount_rate)

# Train the policy optimizer
loss_list, avg_return_list = po.train()
# Out:
# Iteration 1: Average Return = 21.18
# Iteration 2: Average Return = 21.77
# Iteration 3: Average Return = 22.74
# Iteration 4: Average Return = 25.28
# Iteration 5: Average Return = 27.03
# Iteration 6: Average Return = 30.59
# Iteration 7: Average Return = 27.86
# Iteration 8: Average Return = 35.59
# Iteration 9: Average Return = 32.42
# Iteration 10: Average Return = 37.84
# Iteration 11: Average Return = 38.97
# Iteration 12: Average Return = 45.69
# Iteration 13: Average Return = 47.82
# Iteration 14: Average Return = 47.11
# Iteration 15: Average Return = 49.03
# Iteration 16: Average Return = 55.4
# Iteration 17: Average Return = 51.77
# Iteration 18: Average Return = 58.76
# Iteration 19: Average Return = 56.27
# Iteration 20: Average Return = 60.0
# Iteration 21: Average Return = 67.1
# Iteration 22: Average Return = 60.41
# Iteration 23: Average Return = 68.85
# Iteration 24: Average Return = 67.17
# Iteration 25: Average Return = 77.51
# Iteration 26: Average Return = 75.61
# Iteration 27: Average Return = 78.0
# Iteration 28: Average Return = 87.15
# Iteration 29: Average Return = 87.78
# Iteration 30: Average Return = 94.43
# Iteration 31: Average Return = 98.51
# Iteration 32: Average Return = 110.51
# Iteration 33: Average Return = 111.72
# Iteration 34: Average Return = 117.58
# Iteration 35: Average Return = 113.13
# Iteration 36: Average Return = 116.82
# Iteration 37: Average Return = 129.22
# Iteration 38: Average Return = 125.08
# Iteration 39: Average Return = 121.03
# Iteration 40: Average Return = 137.42
# Iteration 41: Average Return = 134.42
# Iteration 42: Average Return = 136.13
# Iteration 43: Average Return = 147.13
# Iteration 44: Average Return = 156.6
# Iteration 45: Average Return = 156.66
# Iteration 46: Average Return = 156.43
# Iteration 47: Average Return = 159.37
# Iteration 48: Average Return = 165.73
# Iteration 49: Average Return = 159.0
# Iteration 50: Average Return = 168.76
# Iteration 51: Average Return = 164.13
# Iteration 52: Average Return = 170.82
# Iteration 53: Average Return = 168.7
# Iteration 54: Average Return = 180.22
# Iteration 55: Average Return = 174.97
# Iteration 56: Average Return = 177.62
# Iteration 57: Average Return = 178.62
# Iteration 58: Average Return = 181.01
# Iteration 59: Average Return = 177.56
# Iteration 60: Average Return = 188.66
# Iteration 61: Average Return = 182.5
# Iteration 62: Average Return = 183.8
# Iteration 63: Average Return = 187.12
# Iteration 64: Average Return = 175.56
# Iteration 65: Average Return = 189.01
# Iteration 66: Average Return = 190.35
# Iteration 67: Average Return = 191.66
# Iteration 68: Average Return = 184.68
# Iteration 69: Average Return = 189.51
# Iteration 70: Average Return = 186.2
# Iteration 71: Average Return = 185.57
# Iteration 72: Average Return = 187.61
# Iteration 73: Average Return = 191.65
# Iteration 74: Average Return = 192.04
# Iteration 75: Average Return = 192.82
# Iteration 76: Average Return = 191.28
# Iteration 77: Average Return = 193.55
# Iteration 78: Average Return = 193.99
# Iteration 79: Average Return = 194.16
# Iteration 80: Average Return = 193.92
# Iteration 81: Average Return = 191.77
# Iteration 82: Average Return = 195.5
# Solve at 82 iterations, which equals 8200 episodes.

# %%
util.plot_curve(loss_list, "loss")
util.plot_curve(avg_return_list, "average return")

# %% [markdown]
# # Problem 6: Generalized Advantage Estimation
#
# In Problem 3, we calculate the advantage function with **the total return substract the baseline**
#
# In Problem 5, we calculate the advantage function based on Problem 3, and **replace the total return with the immediate reward plus estimated baseline**
#
# Here, we use a novel advantage function called "Generalized Advantage Estimation", which introduces one hyperparameter $\lambda$ to compromise the above two estimation methods.
#
# Assume the $\delta_t^i$ represent the i-step bootstrapping (e.g. $\delta_t^i=r_t^i + \gamma*V_{t+1}^i - V_t^i$). The generalized advantage estimation will be:
#
# $$A_{t}^{GAE} = \sum_{l=0}^{\infty} (\gamma\lambda)^l \delta_{t+1}$$
#
# Please see [High-Dimensional Continuous Control Using Generalized Advantage Estimation](https://arxiv.org/abs/1506.02438) for details.
#
#
# If you answer is right, your will solve CartPole with roughly ~ 80 iterations.

# %%
# set the hyperparameter for generalized advantage estimation (GAE)
LAMBDA = 0.98 # \lambda
class PolicyOptimizer_actor_critic(PolicyOptimizer):
    def __init__(self, env, policy, baseline, n_iter, n_episode, path_length,
        discount_rate=.99):
        PolicyOptimizer.__init__(self, env, policy, baseline, n_iter, n_episode, path_length,
            discount_rate=.99)
    
    def process_paths(self, paths):
        for p in paths:
            if self.baseline != None:
                b = self.baseline.predict(p)
                b[-1] = 0 # terminal state
            else:
                b = 0
            
            """
            1. Variable `b` is the reward predicted by our baseline
            2. Calculate the advantage function via one-step bootstrap
                    A(s, a) = [r(s,a,s') + \gamma*v(s')] - v(s)
            3. `target_v` specifies the target of the baseline function
            """
            r = util.discount_bootstrap(p["rewards"], self.discount_rate, b)
            target_v = util.discount_cumsum(p["rewards"], self.discount_rate)
            a = r - b
            
            """
            Problem 6 (Skip this when doing Proble): 
            
            1. in Problem 3, we calculate the advantage function with the total 
                       return substract the baseline 
               in Problem 5, we calculate the advantage function based on Problem 3. 
                       And replace the total return with the immediate reward plus estimated baseline
            2. Here, we use a novel advantage function called "Generalized Advantage Estimation", 
                       which introduces one hyperparameter to balance the above two estimation methods.
            Currently, the variable `LAMBDA` is the default hyperparameter for GAE. 
                        (You're encouraged to try other \lambda=[0,1])
            Sample solution should be only 1 line. (you can use `util.discount` in policy_gradient/util.py)
            """
            # YOUR CODE HERE >>>>>>>>
            a = util.discount(a, self.discount_rate * LAMBDA)
            # <<<<<<<
            p["returns"] = target_v
            p["baselines"] = b
            p["advantages"] = (a - a.mean()) / (a.std() + 1e-8) # normalize

        obs = np.concatenate([ p["observations"] for p in paths ])
        actions = np.concatenate([ p["actions"] for p in paths ])
        rewards = np.concatenate([ p["rewards"] for p in paths ])
        advantages = np.concatenate([ p["advantages"] for p in paths ])

        return dict(
            observations=obs,
            actions=actions,
            rewards=rewards,
            advantages=advantages,
        )

# %%
sess.run(tf.global_variables_initializer())

n_iter = 200
n_episode = 100
path_length = 200
discount_rate = 0.99
# reinitialize the baseline function
baseline = LinearFeatureBaseline(env.spec) 
sess.run(tf.global_variables_initializer())
po = PolicyOptimizer_actor_critic(env, policy, baseline, n_iter, n_episode, path_length,
                     discount_rate)

# Train the policy optimizer
loss_list, avg_return_list = po.train()
# Out:
# Iteration 1: Average Return = 16.07
# Iteration 2: Average Return = 15.7
# Iteration 3: Average Return = 16.81
# Iteration 4: Average Return = 19.64
# Iteration 5: Average Return = 17.86
# Iteration 6: Average Return = 20.05
# Iteration 7: Average Return = 18.97
# Iteration 8: Average Return = 22.3
# Iteration 9: Average Return = 25.73
# Iteration 10: Average Return = 23.87
# Iteration 11: Average Return = 24.86
# Iteration 12: Average Return = 26.85
# Iteration 13: Average Return = 26.69
# Iteration 14: Average Return = 30.26
# Iteration 15: Average Return = 29.88
# Iteration 16: Average Return = 32.52
# Iteration 17: Average Return = 34.43
# Iteration 18: Average Return = 35.7
# Iteration 19: Average Return = 37.23
# Iteration 20: Average Return = 36.47
# Iteration 21: Average Return = 39.89
# Iteration 22: Average Return = 40.35
# Iteration 23: Average Return = 41.02
# Iteration 24: Average Return = 47.09
# Iteration 25: Average Return = 47.48
# Iteration 26: Average Return = 47.9
# Iteration 27: Average Return = 48.69
# Iteration 28: Average Return = 45.78
# Iteration 29: Average Return = 49.9
# Iteration 30: Average Return = 52.77
# Iteration 31: Average Return = 54.94
# Iteration 32: Average Return = 56.82
# Iteration 33: Average Return = 54.65
# Iteration 34: Average Return = 59.01
# Iteration 35: Average Return = 56.34
# Iteration 36: Average Return = 60.78
# Iteration 37: Average Return = 61.74
# Iteration 38: Average Return = 66.1
# Iteration 39: Average Return = 65.43
# Iteration 40: Average Return = 65.89
# Iteration 41: Average Return = 73.45
# Iteration 42: Average Return = 72.86
# Iteration 43: Average Return = 75.69
# Iteration 44: Average Return = 75.77
# Iteration 45: Average Return = 87.74
# Iteration 46: Average Return = 82.89
# Iteration 47: Average Return = 87.39
# Iteration 48: Average Return = 89.09
# Iteration 49: Average Return = 100.18
# Iteration 50: Average Return = 101.33
# Iteration 51: Average Return = 117.09
# Iteration 52: Average Return = 115.05
# Iteration 53: Average Return = 111.64
# Iteration 54: Average Return = 128.7
# Iteration 55: Average Return = 129.93
# Iteration 56: Average Return = 131.83
# Iteration 57: Average Return = 131.58
# Iteration 58: Average Return = 131.02
# Iteration 59: Average Return = 139.8
# Iteration 60: Average Return = 139.11
# Iteration 61: Average Return = 139.51
# Iteration 62: Average Return = 140.51
# Iteration 63: Average Return = 147.13
# Iteration 64: Average Return = 138.8
# Iteration 65: Average Return = 146.24
# Iteration 66: Average Return = 156.64
# Iteration 67: Average Return = 154.95
# Iteration 68: Average Return = 151.77
# Iteration 69: Average Return = 160.44
# Iteration 70: Average Return = 166.34
# Iteration 71: Average Return = 171.93
# Iteration 72: Average Return = 177.03
# Iteration 73: Average Return = 180.15
# Iteration 74: Average Return = 177.52
# Iteration 75: Average Return = 185.1
# Iteration 76: Average Return = 172.98
# Iteration 77: Average Return = 185.79
# Iteration 78: Average Return = 186.09
# Iteration 79: Average Return = 188.9
# Iteration 80: Average Return = 185.11
# Iteration 81: Average Return = 186.51
# Iteration 82: Average Return = 185.95
# Iteration 83: Average Return = 185.34
# Iteration 84: Average Return = 183.55
# Iteration 85: Average Return = 181.3
# Iteration 86: Average Return = 188.47
# Iteration 87: Average Return = 182.39
# Iteration 88: Average Return = 182.54
# Iteration 89: Average Return = 185.0
# Iteration 90: Average Return = 184.55
# Iteration 91: Average Return = 187.24
# Iteration 92: Average Return = 178.24
# Iteration 93: Average Return = 187.34
# Iteration 94: Average Return = 190.13
# Iteration 95: Average Return = 187.12
# Iteration 96: Average Return = 187.05
# Iteration 97: Average Return = 193.72
# Iteration 98: Average Return = 191.99
# Iteration 99: Average Return = 190.08
# Iteration 100: Average Return = 190.32
# Iteration 101: Average Return = 188.43
# Iteration 102: Average Return = 190.83
# Iteration 103: Average Return = 193.2
# Iteration 104: Average Return = 188.79
# Iteration 105: Average Return = 191.13
# Iteration 106: Average Return = 191.09
# Iteration 107: Average Return = 192.86
# Iteration 108: Average Return = 190.63
# Iteration 109: Average Return = 191.28
# Iteration 110: Average Return = 193.36
# Iteration 111: Average Return = 192.55
# Iteration 112: Average Return = 195.4
# Solve at 112 iterations, which equals 11200 episodes.

# %%
util.plot_curve(loss_list, "loss")
util.plot_curve(avg_return_list, "average return")
